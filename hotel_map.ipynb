# %%
import pandas as pd
import numpy as np
import sys
import math
import folium
from folium.plugins import HeatMap
from PIL import Image
from PIL.ExifTags import TAGS, GPSTAGS
import scipy.stats as stats
from xml.dom.minidom import parse, parseString
import matplotlib.pyplot as plt
from math import cos, asin, sqrt, pi

# %%
# give a sample photo
photo = "IMG_1435.JPG"

# %%
def get_exif(filename):
    return Image.open(filename)._getexif()

# test
exif = get_exif(photo)

# %%
def get_geotagging(exif):
    if not exif:
        raise ValueError("No EXIF metadata found")

    geotagging = {}
    for (idx, tag) in TAGS.items():
        if tag == 'GPSInfo':
            if idx not in exif:
                raise ValueError("No EXIF geotagging found")

            for (key, val) in GPSTAGS.items():
                if key in exif[idx]:
                    geotagging[val] = exif[idx][key]

    return geotagging

geotags = get_geotagging(exif)
geotags
# Out:
# {'GPSLatitudeRef': 'N',
#  'GPSLatitude': (49.0, 15.0, 32.96),
#  'GPSLongitudeRef': 'W',
#  'GPSLongitude': (122.0, 53.0, 16.09),
#  'GPSAltitudeRef': b'\x00',
#  'GPSAltitude': 110.72949032433905,
#  'GPSSpeedRef': 'K',
#  'GPSSpeed': 0.0,
#  'GPSImgDirectionRef': 'T',
#  'GPSImgDirection': 268.4230649673609,
#  'GPSDestBearingRef': 'T',
#  'GPSDestBearing': 268.4230649673609,
#  'GPSHPositioningError': 65.0}

# %%
def get_decimal_from_dms(dms, ref):
    degrees = dms[0]
    minutes = dms[1] / 60.0
    seconds = dms[2] / 3600.0

    if ref in ['S', 'W']:
        degrees = -degrees
        minutes = -minutes
        seconds = -seconds

    return round(degrees + minutes + seconds, 5)

def get_coordinates(geotags):
    lat = get_decimal_from_dms(geotags['GPSLatitude'], geotags['GPSLatitudeRef'])

    lon = get_decimal_from_dms(geotags['GPSLongitude'], geotags['GPSLongitudeRef'])

    return (lat,lon)

lat, lon = get_coordinates(geotags)
print(lat)
print(lon)
# Out:
# 49.25916
# -122.8878

# %%
def cal_distance(hotel, lat, lon):
    p = pi / 180
    lat1 = lat 
    lon1 = lon 
    lat2 = hotel['latitude']
    lon2 = hotel['longitude']

    a = 0.5-np.cos((lat2 - lat1) * p)/2 + np.cos(lat1 * p) * np.cos(lat2 * p) * (1 - np.cos((lon2 - lon1) * p)) / 2
    b = 12742*np.arcsin(np.sqrt(a))*1000
   
    return b

# %%
#Read Data and Clean Unnecassary information
hotel = pd.read_csv("listings.csv")
hotel = hotel.drop(['host_id','neighbourhood_group','last_review','reviews_per_month','calculated_host_listings_count' ], axis = 1)
hotel
# Out:
#             id                                               name  \
# 0        10080                     D1 -  Million Dollar View 2 BR
# 1        13358  Monthly (or Longer ) Designer One Bedroom Down...
# 2        13490                       Vancouver's best kept secret
# 3        14267                                  EcoLoft Vancouver
# 4        16254      Close to PNE/Hastings Park Garden level suite
# ...        ...                                                ...
# 4325  50833831  2br-1150 sqft \n4 flrs Furnished Row house Gas...
# 4326  50834014                                            Piplup5
# 4327  50842488  1168 Pendrell S - 2 Bedrooms - Downtown Vancouver
# 4328  50854207             1170 Barclay Street - Brand new Studio
# 4329  50856244         Modern 3BR Laneway House  / Great Location
#
#            host_name             neighbourhood   latitude   longitude  \
# 0               Rami                  Downtown  49.288720 -123.120460
# 1               Lynn                  West End  49.282010 -123.126690
# 2               Iris  Kensington-Cedar Cottage  49.256220 -123.066070
# 3     Peter & Alison  Kensington-Cedar Cottage  49.249220 -123.081390
# 4              Jason          Hastings-Sunrise  49.277210 -123.040860
# ...              ...                       ...        ...         ...
# 4325        Patricia                  Downtown  49.284466 -123.102002
# 4326          Rachel                   Marpole  49.218155 -123.130833
# 4327          Plan A                  West End  49.281144 -123.132688
# 4328          Plan A                  West End  49.285058 -123.128492
# 4329          Gaurav  Kensington-Cedar Cottage  49.234947 -123.082040
#
#             room_type  price  minimum_nights  number_of_reviews  \
# 0     Entire home/apt    150              90                 16
# 1     Entire home/apt     85              30                430
# 2     Entire home/apt    140              30                 89
# 3     Entire home/apt    150               3                 33
# 4     Entire home/apt    195               3                  5
# ...               ...    ...             ...                ...
# 4325  Entire home/apt    103              31                  0
# 4326     Private room     35               1                  0
# 4327  Entire home/apt    147              30                  0
# 4328  Entire home/apt     75              30                  0
# 4329  Entire home/apt    299               1                  0
#
#       availability_365
# 0                  339
# 1                   61
# 2                  195
# 3                    2
# 4                  310
# ...                ...
# 4325               258
# 4326                14
# 4327                62
# 4328                97
# 4329               145
#
# [4330 rows x 11 columns]

# %%
distance = cal_distance(hotel, lat, lon)
hotel['distance'] = distance
hotel
# Out:
#             id                                               name  \
# 0        10080                     D1 -  Million Dollar View 2 BR
# 1        13358  Monthly (or Longer ) Designer One Bedroom Down...
# 2        13490                       Vancouver's best kept secret
# 3        14267                                  EcoLoft Vancouver
# 4        16254      Close to PNE/Hastings Park Garden level suite
# ...        ...                                                ...
# 4325  50833831  2br-1150 sqft \n4 flrs Furnished Row house Gas...
# 4326  50834014                                            Piplup5
# 4327  50842488  1168 Pendrell S - 2 Bedrooms - Downtown Vancouver
# 4328  50854207             1170 Barclay Street - Brand new Studio
# 4329  50856244         Modern 3BR Laneway House  / Great Location
#
#            host_name             neighbourhood   latitude   longitude  \
# 0               Rami                  Downtown  49.288720 -123.120460
# 1               Lynn                  West End  49.282010 -123.126690
# 2               Iris  Kensington-Cedar Cottage  49.256220 -123.066070
# 3     Peter & Alison  Kensington-Cedar Cottage  49.249220 -123.081390
# 4              Jason          Hastings-Sunrise  49.277210 -123.040860
# ...              ...                       ...        ...         ...
# 4325        Patricia                  Downtown  49.284466 -123.102002
# 4326          Rachel                   Marpole  49.218155 -123.130833
# 4327          Plan A                  West End  49.281144 -123.132688
# 4328          Plan A                  West End  49.285058 -123.128492
# 4329          Gaurav  Kensington-Cedar Cottage  49.234947 -123.082040
#
#             room_type  price  minimum_nights  number_of_reviews  \
# 0     Entire home/apt    150              90                 16
# 1     Entire home/apt     85              30                430
# 2     Entire home/apt    140              30                 89
# 3     Entire home/apt    150               3                 33
# 4     Entire home/apt    195               3                  5
# ...               ...    ...             ...                ...
# 4325  Entire home/apt    103              31                  0
# 4326     Private room     35               1                  0
# 4327  Entire home/apt    147              30                  0
# 4328  Entire home/apt     75              30                  0
# 4329  Entire home/apt    299               1                  0
#
#       availability_365      distance
# 0                  339  17196.154769
# 1                   61  17517.494318
# 2                  195  12941.584564
# 3                    2  14093.664170
# 4                  310  11285.454910
# ...                ...           ...
# 4325               258  15793.372483
# 4326                14  18223.877018
# 4327                62  17934.989318
# 4328                97  17698.276275
# 4329               145  14354.236267
#
# [4330 rows x 12 columns]

# %%
def choose_byDistance(hotel, dis):
    return hotel[hotel['distance'] < dis]

hotel_dis = choose_byDistance(hotel, 11000)
hotel_dis
# Out:
#             id                                               name host_name  \
# 6        17158                Vancouver 3br 3ba house 20min to DT    Elaine
# 49      306178                    Sunset views - LGBTQ2+ friendly  Michelle
# 59      461370                  Lovely large room w/ private bath      Nala
# 60      461386                  Beautiful room (s) Vancouver Home      Nala
# 168    2084273                  Gorgeous New House Double Ensuite     Renee
# ...        ...                                                ...       ...
# 4229  50424076          Private 1 Bedroom suite in East Vancouver  Min Ming
# 4246  50528364  Modern yet Cozy house in Vancouver w/ 2 bed 2 ...       Sue
# 4306  50775791                      Near Metrotown Joyce skytrain       Yan
# 4311  50780432                  Brand New Spacious & Central Home    Kashif
# 4312  50780970                            Be away for summer hot！     Xiuci
#
#             neighbourhood   latitude   longitude        room_type  price  \
# 6     Renfrew-Collingwood  49.252770 -123.037740  Entire home/apt    185
# 49    Renfrew-Collingwood  49.232730 -123.027470     Private room     70
# 59              Killarney  49.228340 -123.030470     Private room     84
# 60              Killarney  49.230340 -123.029710     Private room     84
# 168   Renfrew-Collingwood  49.249760 -123.035470     Private room     75
# ...                   ...        ...         ...              ...    ...
# 4229     Hastings-Sunrise  49.268740 -123.031310  Entire home/apt     71
# 4246  Renfrew-Collingwood  49.249510 -123.037090  Entire home/apt     94
# 4306  Renfrew-Collingwood  49.237674 -123.022643     Private room     45
# 4311     Hastings-Sunrise  49.286057 -123.029172  Entire home/apt    550
# 4312  Renfrew-Collingwood  49.242392 -123.019537  Entire home/apt    123
#
#       minimum_nights  number_of_reviews  availability_365      distance
# 6                  4                  5                 1  10905.036759
# 49                 2                 72               130  10555.936635
# 59                30                 44               365  10909.077475
# 60                30                 35               365  10788.379098
# 168               31                 41               334  10768.294270
# ...              ...                ...               ...           ...
# 4229               2                  0                24  10467.866016
# 4246              30                  0               313  10888.051526
# 4306               1                  0               332  10075.106197
# 4311               2                  0                14  10683.712456
# 4312               2                  0               362   9741.870232
#
# [108 rows x 12 columns]

# %%
def choose_nearest(hotel):
    return hotel[hotel['distance'] == hotel['distance'].min()]

hotel_nearest = choose_nearest(hotel)
hotel_nearest
# Out:
#             id                     name host_name        neighbourhood  \
# 4312  50780970  Be away for summer hot！     Xiuci  Renfrew-Collingwood
#
#        latitude   longitude        room_type  price  minimum_nights  \
# 4312  49.242392 -123.019537  Entire home/apt    123               2
#
#       number_of_reviews  availability_365     distance
# 4312                  0               362  9741.870232

# %%
def choose_byRegion(hotel, region):
    return hotel[hotel['neighbourhood'] == region]

hotel_region = choose_byRegion(hotel, 'Downtown')
hotel_region
# Out:
#             id                                               name  host_name  \
# 0        10080                     D1 -  Million Dollar View 2 BR       Rami
# 18       26047    The Alpha Downtown Accommodation by COMFYSUITES     Alicia
# 19       32746                 Designer Urban Park View Townhouse    Liliana
# 21       35102                 Downtown Yaletown Trendy 2 Bd/2Bth     Karina
# 23       42645                         The Charlie by COMFYSUITES     Alicia
# ...        ...                                                ...        ...
# 4296  50734168  Downtown 2BD/2BA/Den+Amazing View+Skytrain+Par...    Lillian
# 4318  50796676   Cute and Cozy Studio in the Heart of DT/Yaletown      Salim
# 4321  50817305    Beautiful 2BR in Downtown+FreePKG+1mintoHarbour        Ash
# 4322  50823438          Gorgeous View - Private Condo ( WITH AC )  Hoang Yen
# 4325  50833831  2br-1150 sqft \n4 flrs Furnished Row house Gas...   Patricia
#
#      neighbourhood   latitude   longitude        room_type  price  \
# 0         Downtown  49.288720 -123.120460  Entire home/apt    150
# 18        Downtown  49.280860 -123.123750  Entire home/apt    159
# 19        Downtown  49.279200 -123.105000  Entire home/apt     99
# 21        Downtown  49.277430 -123.118690  Entire home/apt    132
# 23        Downtown  49.280360 -123.123400  Entire home/apt    159
# ...            ...        ...         ...              ...    ...
# 4296      Downtown  49.279370 -123.108310  Entire home/apt    299
# 4318      Downtown  49.276267 -123.131674  Entire home/apt     76
# 4321      Downtown  49.278490 -123.106440  Entire home/apt    257
# 4322      Downtown  49.277796 -123.107704  Entire home/apt    220
# 4325      Downtown  49.284466 -123.102002  Entire home/apt    103
#
#       minimum_nights  number_of_reviews  availability_365      distance
# 0                 90                 16               339  17196.154769
# 18                30                 35               297  17288.358048
# 19                30                 80               335  15915.786350
# 21                30                 76                 0  16875.331898
# 23                30                 30               319  17255.615671
# ...              ...                ...               ...           ...
# 4296               2                  0               360  16156.205055
# 4318              30                  0               123  17796.842465
# 4321               1                  0               335  16008.565541
# 4322               3                  1               256  16089.463669
# 4325              31                  0               258  15793.372483
#
# [1170 rows x 12 columns]

# %%
def choose_byReviews(hotel):
    return hotel[hotel['number_of_reviews'] == hotel['number_of_reviews'].max()]

hotel_review = choose_byReviews(hotel)
hotel_review
# Out:
#           id                                name  host_name neighbourhood  \
# 272  3812348  Cosy room near scenic park, pvt BR  Catherine    Riley Park
#
#      latitude  longitude     room_type  price  minimum_nights  \
# 272   49.2357 -123.10428  Private room     75               2
#
#      number_of_reviews  availability_365      distance
# 272                662                32  15928.761887

# %%
def choose_byPrice(hotel, price):
    return hotel[hotel['price'] < price]

hotel_price = choose_byPrice(hotel, 100)
hotel_price
# Out:
#             id                                               name  \
# 1        13358  Monthly (or Longer ) Designer One Bedroom Down...
# 7        17765            Central location, nice little apartment
# 8        18270                private rm in clean central 2BR apt
# 9        18589                               Commercial Drive B&B
# 11       18795              *Best choice in downtown-5 Stars * -2
# ...        ...                                                ...
# 4316  50795092      Artsy Private Guest Suite with Outdoor Saloon
# 4318  50796676   Cute and Cozy Studio in the Heart of DT/Yaletown
# 4320  50813864         Private room with shared bathroom near UBC
# 4326  50834014                                            Piplup5
# 4328  50854207             1170 Barclay Street - Brand new Studio
#
#              host_name       neighbourhood   latitude   longitude  \
# 1                 Lynn            West End  49.282010 -123.126690
# 7                James      Mount Pleasant  49.261320 -123.108450
# 8                  Ran      Mount Pleasant  49.265570 -123.096000
# 9     Sylvain & Alexis  Grandview-Woodland  49.275690 -123.070570
# 11                 Kai            West End  49.282990 -123.130080
# ...                ...                 ...        ...         ...
# 4316            Jordan          Riley Park  49.248690 -123.105020
# 4318             Salim            Downtown  49.276267 -123.131674
# 4320               Liz         Shaughnessy  49.248621 -123.127759
# 4326            Rachel             Marpole  49.218155 -123.130833
# 4328            Plan A            West End  49.285058 -123.128492
#
#             room_type  price  minimum_nights  number_of_reviews  \
# 1     Entire home/apt     85              30                430
# 7     Entire home/apt     94               3                194
# 8        Private room     50              30                118
# 9        Private room     79               1                390
# 11       Private room     85              30                122
# ...               ...    ...             ...                ...
# 4316  Entire home/apt     89               1                  1
# 4318  Entire home/apt     76              30                  0
# 4320     Private room     67               1                  0
# 4326     Private room     35               1                  0
# 4328  Entire home/apt     75              30                  0
#
#       availability_365      distance
# 1                   61  17517.494318
# 7                    0  16014.038737
# 8                  280  15124.913449
# 9                    1  13388.185694
# 11                 365  17776.628048
# ...                ...           ...
# 4316               309  15808.272456
# 4318               123  17796.842465
# 4320               117  17455.067857
# 4326                14  18223.877018
# 4328                97  17698.276275
#
# [1359 rows x 12 columns]

# %%
def choose_lowestPrice(hotel):
    return hotel[hotel['price'] == hotel['price'].min()]

hotel_lowprice = choose_lowestPrice(hotel)
hotel_lowprice
# Out:
#             id                                  name host_name  \
# 2113  32272216  1 bright bdrm with large shared bath     Kitty
#
#                  neighbourhood  latitude  longitude     room_type  price  \
# 2113  Kensington-Cedar Cottage  49.23933 -123.08915  Private room     12
#
#       minimum_nights  number_of_reviews  availability_365      distance
# 2113              30                  3               283  14780.322267

# %%
hotel_filter = hotel_price = choose_byPrice(hotel, 100)
hotel_filter = choose_region(hotel_filter, 'Downtown')
hotel_filter = choose_byDistance(hotel_filter, 20000)
hotel_filter
# Out:
#             id                                               name host_name  \
# 19       32746                 Designer Urban Park View Townhouse   Liliana
# 46      258636                FABULOUS Luxury Downtown Vancouver!       Ian
# 99      980511                     261 Yaletown Studio at "Space"     Bruce
# 100     994969                            152 Studio (no Bedroom)     Bruce
# 105    1021607                 Deluxe Junior One Bedroom (2 Beds)    Hajime
# ...        ...                                                ...       ...
# 4175  50116004  Executive one bed- condo in the heart of YaleT...       Jas
# 4195  50229369  Beautiful 1 bedroom in Yaletown with free parking      Kira
# 4247  50542042  4Months or Longer- City View LUXURY Yaletown C...    Anelia
# 4252  50554509         Brand new 1 Bed + Den close to Water front    Cayden
# 4318  50796676   Cute and Cozy Studio in the Heart of DT/Yaletown     Salim
#
#      neighbourhood   latitude   longitude        room_type  price  \
# 19        Downtown  49.279200 -123.105000  Entire home/apt     99
# 46        Downtown  49.278390 -123.128520  Entire home/apt     99
# 99        Downtown  49.274890 -123.126540  Entire home/apt     70
# 100       Downtown  49.280060 -123.126730  Entire home/apt     61
# 105       Downtown  49.277470 -123.120980  Entire home/apt     70
# ...            ...        ...         ...              ...    ...
# 4175      Downtown  49.276855 -123.125221  Entire home/apt     85
# 4195      Downtown  49.274680 -123.124710  Entire home/apt     90
# 4247      Downtown  49.276270 -123.114300  Entire home/apt     94
# 4252      Downtown  49.277122 -123.128647  Entire home/apt     95
# 4318      Downtown  49.276267 -123.131674  Entire home/apt     76
#
#       minimum_nights  number_of_reviews  availability_365      distance
# 19                30                 80               335  15915.786350
# 46               120                 53                97  17596.069495
# 99                30                  7                46  17410.698929
# 100               30                  1                 3  17490.576536
# 105               30                100                13  17040.813851
# ...              ...                ...               ...           ...
# 4175              30                  0               295  17338.574231
# 4195              30                  0               102  17276.282094
# 4247             120                  0               148  16544.032196
# 4252              30                  0               126  17588.870933
# 4318              30                  0               123  17796.842465
#
# [197 rows x 12 columns]

# %%
hotel_filter = choose_byReviews(hotel_filter)
hotel_filter
# Out:
#           id                                          name host_name  \
# 415  6808688  Bright room, Amazing View, Heart of Downtown     Laulé
#
#     neighbourhood  latitude  longitude     room_type  price  minimum_nights  \
# 415      Downtown  49.28945 -123.12525  Private room     61              30
#
#      number_of_reviews  availability_365      distance
# 415                335               141  17552.649138

# %%
# define the world map
amen = pd.read_json('amenities-vancouver.json.gz', lines=True)
van_map = folium.Map(location=[lat, lon], zoom_start=12)

incidents = folium.map.FeatureGroup()

folium.Marker(
        location=[lat, lon],
        popup="My postion",
        icon=folium.Icon(icon="home"),
    ).add_to(van_map)
van_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c8bd96cc0aa14288adbb85b7b3d54958%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c8bd96cc0aa14288adbb85b7b3d54958%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c8bd96cc0aa14288adbb85b7b3d54958%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c8bd96cc0aa14288adbb85b7b3d54958%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.276266645109935%2C%20-122.8878%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
incidents = folium.map.FeatureGroup()
latitudes = list(hotel_filter.latitude)
longitudes = list(hotel_filter.longitude)
labels = list(hotel_filter.name)
for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(van_map)
van_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c8bd96cc0aa14288adbb85b7b3d54958%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c8bd96cc0aa14288adbb85b7b3d54958%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c8bd96cc0aa14288adbb85b7b3d54958%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c8bd96cc0aa14288adbb85b7b3d54958%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.276266645109935%2C%20-122.8878%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
df = pd.DataFrame({'origin_lng' : lon, 'origin_lat' : lat,
                   'destination_lng': hotel_filter['longitude'], 'destination_lat': hotel_filter['latitude']})

print(df.head())
# Out:
#      origin_lng  origin_lat  destination_lng  destination_lat
# 272   -122.8878     49.2357       -123.10428          49.2357

# %%
folium.CircleMarker([row['origin_lat'], row['origin_lng']],
                        radius=15,
                        fill_color="#3db7e4", # divvy color
                       ).add_to(van_map)

folium.CircleMarker([row['destination_lat'], row['destination_lng']],
                        radius=15,
                        fill_color="red", # divvy color
                       ).add_to(van_map)

folium.PolyLine([[row['origin_lat'], row['origin_lng']], 
                     [row['destination_lat'], row['destination_lng']]]).add_to(van_map)
van_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2c2b058d7d9140b7b23259bfa524f4f0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2c2b058d7d9140b7b23259bfa524f4f0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2c2b058d7d9140b7b23259bfa524f4f0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2c2b058d7d9140b7b23259bfa524f4f0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.25916%2C%20-122.8878%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
